# %%
def display_board(board):
    
    print('   |   |   ')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |   ')
    print('-----------')
    print('   |   |   ')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |   ')
    print('-----------')
    print('   |   |   ')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |   ')

    
def player_input():
    
    marker = ''
    
    while marker not in ['X','O']:
        marker = (input('\nPlayer1, Please choose X or O: \n'))
        
        if marker not in ['X','O']:
            print('\nSorry! Can only choose between X or O')
        else:
            pass
        
    player1 = marker
    
    if player1 == 'X':
        player2 = 'O'
    else:
        player2 = 'X'
        
        
    return (player1,player2)





def positional():
    
    player1 = ''
    
    while player1 not in ['1','2','3','4','5','6','7','8','9']:
        player1 = (input('\nPlayer1, choose between 1-9: '))
        
        if player1 not in ['1','2','3','4','5','6','7','8','9']:
            print('Invalid! Please Choose (1-9).')
            
    return int(player1)




def positional2():
    
    player2 = ''
    while player2 not in ['1','2','3','4','5','6','7','8','9']:
        player2 = (input('\nPlayer2, choose between 1-9: '))
        
        if player2 not in ['1','2','3','4','5','6','7','8','9']:
            print('Invalid! Please Choose (1-9).')
            
    return int(player2)




def assigner(position):
    
    if Player1 == 'X':
        test_board[position] = 'X'
    elif Player1 == 'O':
        test_board[position] = 'O'
        
    return test_board




def assigner2(position2):
    
    if Player2 == 'X':
        test_board[position2] = 'X'
    elif Player2 == 'O':
        test_board[position2] = 'O'
        
    return test_board
      
    
def assigner2(position2):
    
    if Player2 == 'X':
        test_board[position2] = 'X'
    elif Player2 == 'O':
        test_board[position2] = 'O'
        
    return test_board





def win_check1(test_board):
    if (test_board[1:4] == ['X','X','X']) or (test_board[4:7] == ['X','X','X']) or (test_board[7:10] == ['X','X','X']):
        print('Congratulation! Player with X won the game.')
        return True
    elif test_board[1:8:3] == ['X','X','X'] or  test_board[2:9:3] == ['X','X','X'] or test_board[3:10:3] == ['X','X','X']:
        print('Congratulation! Player with X won the game.')
        return True
    elif test_board[1:10:4] == ['X','X','X'] or test_board[3:8:2] == ['X','X','X']:
        print('Congratulation! Player with X won the game.')
        return True
    else:
        return False
    
    
    
def win_check2(test_board):
    if (test_board[1:4] == ['O','O','O']) or (test_board[4:7] == ['O','O','O']) or (test_board[7:10] == ['O','O','O']):
        print('Congratulation! Player with O won the game.')
        return True
    elif test_board[1:8:3] == ['O','O','O'] or  test_board[2:9:3] == ['O','O','O'] or test_board[3:10:3] == ['O','O','O']:
        print('Congratulation! Player with O won the game.')
        return True
    elif test_board[1:10:4] == ['O','O','O'] or test_board[3:8:2] == ['O','O','O']:
        print('Congratulation! Player with O won the game.')
        return True
    else:
        return False
    
    
    
       
def game_on(test_board):
    gameon = True
    if ' ' in test_board:
        pass
    else:
        print('\nStalemate!')
        gameon = False
    
    return gameon


test_board = [' ']*10

test_board[0] = '#'

gameon = True

game = True

win1 = False

win2 = False

Player1,Player2 = player_input()

display_board(test_board)

while (win1 == False) and (win2 == False) and gameon == True:
    
    while game == True and ((win1 == False) or (win2 == False)):
        
        position = positional()
        
        if test_board[position] == 'X' or test_board[position] ==  'O':
            print('Error! Position Already Occupied! Choose different position.')
            continue
        else:
            pass
    
       
        assigner(position)
    
        test_board = assigner(position)
    
        display_board(test_board)
        
        win1 = win_check1(test_board)
        
        win2 = win_check2(test_board)
        
        if (win1 == True) or (win2 == True):
            break
    
        game = False
        
        gameon = game_on(test_board)
    
    while not game and ((win1 == False) or (win2 == False)) and gameon == True:
        
        position2 = positional2()
        
        if test_board[position2] == 'X' or test_board[position2] ==  'O':
            print('Error! Position Already Occupied! Choose different position.')
            continue
        else:
            pass
    
    
        assigner2(position2)
    
        test_board = assigner2(position2)
    
        display_board(test_board)
        
        win1 = win_check1(test_board)
        
        win2 = win_check2(test_board)
        
        if (win1 == True) or (win2 == True):
            break
    
        game = True
        
        gameon = game_on(test_board)
# Out:
# Player1, Please choose X or O:
# X
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# Player1, choose between 1-9: 5
#    |   |
#    |   |
#    |   |
# -----------
#    |   |
#    | X |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# Player2, choose between 1-9: 9
#    |   |
#    |   | O
#    |   |
# -----------
#    |   |
#    | X |
#    |   |
# -----------
#    |   |
#    |   |
#    |   |
#
# Player1, choose between 1-9: 1
#    |   |
#    |   | O
#    |   |
# -----------
#    |   |
#    | X |
#    |   |
# -----------
#    |   |
#  X |   |
#    |   |
#
# Player2, choose between 1-9: 3
#    |   |
#    |   | O
#    |   |
# -----------
#    |   |
#    | X |
#    |   |
# -----------
#    |   |
#  X |   | O
#    |   |
#
# Player1, choose between 1-9: 6
#    |   |
#    |   | O
#    |   |
# -----------
#    |   |
#    | X | X
#    |   |
# -----------
#    |   |
#  X |   | O
#    |   |
#
# ...
